# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage

# %%
img = cv2.imread('Yericho Gans.jpg')

# %%
cv2.imshow("Yericho", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
edges = cv2.Canny(img, 170, 170)

# %%
cv2.imshow("Yericho 2", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fig, axs = plt.subplots(1,2, figsize =(20,10))
ax = axs.ravel()

ax[0].imshow(img_rgb)
ax[0].set_title("Original")

ax[1].imshow(edges, cmap = "gray")
ax[1].set_title("Canny Edge")
# Out:
# Text(0.5, 1.0, 'Canny Edge')

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
edges = cv2.Canny(img, 100, 150)

# %%
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
img_contours = img_rgb.copy()
cv2.drawContours(img_contours, contours, -1, (0, 255, 0), 2)
# Out:
# array([[[ 93,  95,  84],
#         [ 93,  95,  84],
#         [ 93,  95,  84],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 93,  95,  84],
#         [ 93,  95,  84],
#         [ 93,  95,  84],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[ 92,  94,  83],
#         [ 92,  94,  83],
#         [ 93,  95,  84],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 51,  77,  16],
#         [ 51,  77,  16],
#         [ 53,  79,  18],
#         ...,
#         [128, 119, 102],
#         [127, 118, 101],
#         [125, 116,  99]],
#
#        [[ 51,  77,  16],
#         [ 51,  77,  16],
#         [ 53,  79,  18],
#         ...,
#         [128, 119, 102],
#         [126, 117, 100],
#         [125, 116,  99]],
#
#        [[ 51,  77,  16],
#         [ 51,  77,  16],
#         [ 53,  79,  18],
#         ...,
#         [128, 119, 102],
#         [126, 117, 100],
#         [124, 115,  98]]], dtype=uint8)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 10))
axs[0].imshow(img_rgb)
axs[0].set_title("Original Image")

axs[1].imshow(edges, cmap='gray')
axs[1].set_title("Canny Edge")

axs[2].imshow(img_contours)
axs[2].set_title("Contours Detection")

plt.show()

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi/250, 20, maxLineGap = -50)
img_line = img.copy()

# %%
for line in lines:
    x1, y1, x2, y2, = line[0]
    cv2.line(img_line,(x1,y1),(x2,y2),(100, 8, 255), 3)

# %%
fig,axs = plt.subplots(1,2,figsize = (10,10))
ax = axs.ravel()

ax[0].imshow(gray, cmap = "gray")
ax[0].set_title("Original Image")

ax[1].imshow(img_line, cmap = "gray")
ax[1].set_title("Image Line")

plt.show()
